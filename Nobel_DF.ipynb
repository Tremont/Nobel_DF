# %%
import pandas as pd
import matplotlib.pyplot as plt
import sqlite3
import numpy as np

nobeldf = pd.read_csv('archive.csv')
conn = sqlite3.connect("archive.db")
conn.execute('DROP TABLE IF EXISTS NOBEL_LAU')
conn.execute('''CREATE TABLE NOBEL_LAU (ID INT PRIMARY KEY NOT NULL, Category,
Prize,
Motivation,
Prize_Share,
Laureate_ID,
Laureate_Type,
Full_Name,
Birth_Date,
Birth_City,
Birth_Country,
Sex,Organization_Name,
Organization_City,
Organization_Country,
Death_Date,
Death_City,
Death_Country);''')
            




conn.commit()

# %%
df = pd.read_csv("c:/users/djuan/downloads/archive.csv")
df.to_sql("nobel", conn, if_exists ='replace', index = False)

# %%
gender = pd.read_sql_query('select sex from nobel ASC limit 154', conn)

# %%
MF = gender.Sex.value_counts()

# %%
MF.plot.bar()

# %%
OrgCo = pd.read_sql_query('SELECT Prize, Organization_Country FROM nobel WHERE Organization_Country = "United States of America" ', conn)

# %%
pd.read_sql_query('SELECT Organization_Country, Sex FROM nobel WHERE Sex = "Male" ', conn)
# Out:
#          Organization_Country   Sex
# 0                     Germany  Male
# 1                        None  Male
# 2                     Germany  Male
# 3                        None  Male
# 4                        None  Male
# 5                     Germany  Male
# 6                     Germany  Male
# 7                        None  Male
# 8              United Kingdom  Male
# 9                        None  Male
# 10                       None  Male
# 11                Netherlands  Male
# 12                Netherlands  Male
# 13                     Sweden  Male
# 14                       None  Male
# 15                    Denmark  Male
# 16                       None  Male
# 17                     France  Male
# 18                     France  Male
# 19             United Kingdom  Male
# 20                       None  Male
# 21                       None  Male
# 22                     Russia  Male
# 23             United Kingdom  Male
# 24                    Germany  Male
# ...

# %%
pd.read_sql_query('SELECT Prize, Organization_Country FROM nobel WHERE Organization_Country = "United States of America" ', conn)
# Out:
#                                                  Prize  \
# 0                      The Nobel Prize in Physics 1907
# 1       The Nobel Prize in Physiology or Medicine 1912
# 2                    The Nobel Prize in Chemistry 1914
# 3                      The Nobel Prize in Physics 1923
# 4                      The Nobel Prize in Physics 1927
# 5       The Nobel Prize in Physiology or Medicine 1930
# 6                           The Nobel Peace Prize 1931
# 7                    The Nobel Prize in Chemistry 1932
# 8       The Nobel Prize in Physiology or Medicine 1933
# 9                    The Nobel Prize in Chemistry 1934
# 10      The Nobel Prize in Physiology or Medicine 1934
# 11      The Nobel Prize in Physiology or Medicine 1934
# 12      The Nobel Prize in Physiology or Medicine 1934
# 13      The Nobel Prize in Physiology or Medicine 1934
# 14                     The Nobel Prize in Physics 1936
# 15                     The Nobel Prize in Physics 1937
# ...

# %%
Germany = pd.read_sql_query('SELECT Organization_Country, Prize FROM nobel WHERE (Prize LIKE "%Chemistry%") AND (Organization_Country LIKE "%Germany%") ', conn)

# %%
USA = pd.read_sql_query('SELECT Organization_Country, Prize FROM nobel WHERE (Prize LIKE "%Chemistry%") AND (Organization_Country LIKE "%States%") ', conn)

# %%
USPrize = USA.count()

# %%
GerPrize = Germany.count()

# %%
GerPrize.value_counts()
# Out:
# 38    2
# dtype: int64

# %%
GerCount = pd.read_sql_query('SELECT Organization_Country from nobel WHERE Organization_Country = "Germany"  ', conn)

# %%
USCount = pd.read_sql_query('SELECT Organization_Country FROM nobel WHERE Organization_Country = "United States of America" ', conn)

# %%
GerC= GerCount.count()

# %%
USC = USCount.count()

# %%
pd.read_sql_query('SELECT Organization_Country FROM nobel WHERE Organization_Country ="France" and Sex ="Female"', conn)
# Out:
#   Organization_Country
# 0               France
# 1               France
# 2               France

# %%
Chem = pd.read_sql_query('SELECT Organization_Country FROM nobel WHERE Prize LIKE "%Chemistry%" ORDER BY Organization_Country ASC LIMIT 154 ', conn)

# %%
USCount.dtypes
# Out:
# Organization_Country    object
# dtype: object

# %%
ChemCounts = Chem.Organization_Country.value_counts()

# %%
ChemCounts.plot.bar()
plt.title('The number of times Nobel Prize Chemistry Over last 10 years')
# Out:
# Text(0.5,1,'The number of times Nobel Prize Chemistry Over last 10 years')

# %%
plt.pie(ChemCounts)
#plt.pie()
plt.show()

# %%
pd.read_sql_query('SELECT Organization_Country FROM nobel', conn)
# Out:
#          Organization_Country
# 0                     Germany
# 1                        None
# 2                     Germany
# 3                        None
# 4                        None
# 5                     Germany
# 6                     Germany
# 7                        None
# 8              United Kingdom
# 9                        None
# 10                       None
# 11                Netherlands
# 12                Netherlands
# 13                     Sweden
# 14                       None
# 15                    Denmark
# 16                       None
# 17                     France
# 18                     France
# 19                       None
# 20             United Kingdom
# 21                       None
# 22                       None
# 23                     Russia
# 24                       None
# 25             United Kingdom
# 26                    Germany
# 27                       None
# 28                    Germany
# 29                       None
# ...
